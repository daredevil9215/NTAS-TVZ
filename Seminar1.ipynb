# %% [markdown]
# # OPIS ZADATKA

# %% [markdown]
# Korištenjem AVL balansiranog stabla implementirati stablo za indeksiranje zapisa iz baze podataka. Baza podataka u obliku tekstualne datoteke sadrži zapise o filmovima. Podatkovni skup je zadan u datoteci *movie.txt* te se sastoji od preko 500,000 zapisa.

# %% [markdown]
# Prikaz isječka iz podatkovnog skupa:
#
# ![filmovi-3.png](attachment:filmovi-3.png)

# %% [markdown]
# Struktura zapisa u datotekama je takva da su dijelovi odnosno polja zapisa odvojena tabulatorom ("\t") unutar jednog retka datoteke. Prilikom čitanja podataka, zapise iz datoteke treba čitati redak po redak te za svaki zapis izdvojiti dijelove zapisa kao zasebna polja te nad njima napraviti čišćenje praznih znakova.
#
# Prema tome treba realizirati odgovarajuću strukturu zapisa podatka, primjerice razred naziva *MoviesData*, za potrebe pohrane podataka iz datoteke a koja bi prema sadržaju zapisa trebao imati atribute koje se odnose na ID zapisa cjelobrojnog tipa te kraći i duži naziv filma tekstualnog tipa.
#
# Stablo indeksa treba oblikovati po atributu koji se odnosi na kraći naziv filma.
#
# Kao polazište implementacije zadataka mogu se iskoristiti kodovi koji su dani ispod te ih onda treba prilagoditi odnosno dopuniti sukladno zahtjevima zadataka:
#
# * U razredu *BinaryNode*: potrebno je proširiti čvor stabla s objektom razreda *MoviesData*, a postojeća vrijednost *value* razreda *BinaryNode* bi trebala biti indeksni ključ.
# * Konstruktor odnosno \_\_init\_\_() metoda treba primiti dvije vrijednosti: ključ (*value*) i objekt navedenog tipa.
# * Metodu *add()* za umetanje novog čvora također treba urediti sukladno proširenju implementacije.

# %% [markdown]
# ## ZADACI KOJE TREBA IMPLEMENTIRATI
#
# a) Na temelju sadržaja tekstualne datoteke treba izgraditi AVL stablo uporabom razreda *BinaryTree* temeljem kraćeg naziva filma kao indeksnog ključa. Ispisati visinu dobivenog AVL stabla.
#
# b) Implementirati pretraživanje podataka o filmu uporabom implementiranog indeksa i to tako da se za traženje može zadati kraći naziv filma cjelovito ili djelomično u obliku prefiksa korištenjem znaka '\*'. Primjerice, može se unijeti cjeloviti naziv 'Bugsy' ili samo dio odnosno prefiks naziva 'Bug*'. Nakon što je podatak pronađen treba ispisati cijeli zapis: ID, kraći naziv, duži naziv.
#
# c) Implementirati funkciju za traženje u rangu npr. sve filmove od 'Pick*' do 'Ten*', ili od 'F*' do 'M*'. Rangove treba moći zadati proizvoljno.
#
# d) Ispisati minimalnu i maksimalnu vrijednost indeksa i pripadnih podataka za te indekse.
#
# e) Za proizvoljno zadani cijeli broj koji će imati značenje rednog broja te slijedom toga ispisati visinu čvora koji se nalazi na tom rednom broju u uzlazno sortiranom redoslijedu indeksnih ključeva stabla.
#
# f) Napraviti metode za ispis broja lijevih rotacija i broja desnih rotacija kod umetanja čvora u stablo.
#
# g) Ispisati stablo po razinama počevši od korijena prema dolje u cik-cak redoslijedu. To znači da se čvorovi na prvoj razini ispisuju s lijeva na desno, na drugoj razini s desna na lijevo, pa na trećoj razini s lijeva na desno itd. Ispis raditi po razinama, odnosno svaku razinu ispisati u posebnom retku.
# Primjer za stablo na slici treba dobiti sljedeći ispis:
#
# ![primjer2.png](attachment:primjer2.png)
#
# Zbog velikog broja podataka dovoljno je ispisati samo prvih 10 razina.
#
# h) Nasumično birati zapise iz skupa podataka i graditi obično nebalansirano binarno stablo pretraživanja sve dok je to moguće. Zabilježiti visinu takvog nebalansiranog stabla te ponoviti postupak za isti niz zapisa u izgradnji AVL stabla za koji također treba zabilježiti visinu dobivenog stabla.

# %% [markdown]
# # SADRŽAJ RADA

# %% [markdown]
# ## Opis i analiza složenosti poduzetih postupaka

# %% [markdown]
# ***

# %% [markdown]
# a) U AVL stablo učitava se 30000 redaka (filmova). Funkcija korištena za učitavanje filmova *get_movies_from_file()* je reda složenosti $O(1)$ jer uvijek učitava konstantan broj (30000) filmova. Potom se u AVL stablo dodaje svaki film for petljom koja isto ima složenost $O(1)$ zbog konstantnog broja filmova.

# %% [markdown]
# b) Pretraživanje se obavlja funkcijama *search_keys()* i *find_matching_keys_recursive()*. Kompiliranje regex uzorka u *search_keys()* je reda složenosti $O(m)$ gdje je $m$ duljina uzorka te rekurzivno pretraživanje stabla u *find_matching_keys_recursive()* gdje treba u najgorem slučaju proći svaki čvor je $O(n)$. Stoga je cijela implementacija reda složenosti $O(n)$.

# %% [markdown]
# c) Pretraživanje se obavlja funkcijama *search_keys_in_range()* i *search_keys_in_range_recursive*. Kompiliranje regex uzorka u *search_keys_in_range()* je reda složenosti $O(m)$ gdje je $m$ duljina uzorka te rekurzivno pretraživanje stabla u *find_matching_keys_recursive()* gdje treba proći raspon čvorova je $O(\log n + k)$ gdje $k$ broj čvorova u rasponu te $n$ broj čvorova. Stoga je cijela implementacija reda složenosti $O(\log n)$.

# %% [markdown]
# d) Pretraživanje minimalnog i maksimalnog indeksa obavlja se funkcijom *find_min_max_indices()* koja je reda složenosti $O(n)$ jer mora proći sve čvorove stabla kako bi obavila usporedbu sa svakim čvorom. Inicijaliziraju se "maksimalni" i "minimalni" stringovi te se rade usporedbe sa svakim čvorom.

# %% [markdown]
# e) Prvo se funkcijom *get_sorted_indices()* sortiraju svi indeksi (imena filmova) pohranjeni u listi. Pythonova list metoda sort() se izvodi Timsort algoritmom čija je složenost $O(n \log n)$. Funkcija *print_node_height()* pronalazi određeni čvor što je reda složenosti $O(n)$ jer potencijalno mora proći kroz sve čvorove drva. Prevladavajuća radnja je sortiranje reda $O(n \log n)$ stoga je cijela implementacija reda $O(n \log n)$.

# %% [markdown]
# f) Funkcijom *search_node()* pretražuje se stablo dok se ne nađe čvor što je reda složenosti $O(\log n)$. Funkcijom *print_rotations()* ispisuju se atributi (kojima je proširen razred BinaryNode) čvorova *left_rotations* i *right_rotations* što je operacija reda $O(1)$. Inicijalno pri stvaranju čvora ovi atributi su postavljeni na vrijednost 0 te tokom dodavanja u drvo u metodi *add()* se vrijednosti rotacija mijenjaju. Ukupna složenost ove implementacije je $O(\log n)$ zbog pretraživanja.

# %% [markdown]
# g) Ispis stabla u cik-cak redoslijedu realiziran je funkcijom *print_levels_zig_zag()*. Prolazak kroz stablo je reda složenosti $O(n)$ jer mora proći svaki čvor kako bi se ispisao. Ispis je napravljen pomoću Python razreda *deque* čije operacije *append* i *popleft* su konstantne složenosti $O(1)$. Implementacija je stoga složenosti $O(n)$.

# %% [markdown]
# h) Dodana je implementacija običnog binarnog stabla *BinaryTreeNonAVL* kako bi se maknulo svojstvo balansiranja. Ubacivanje čvora u AVL stablo je reda složenosti $O(\log n)$, a u nebalansirano binarno stablo $O(n)$. Ispis visina je konstante složenosti, stoga je prevladavajuća složenost reda $O(n)$.

# %% [markdown]
# ***

# %% [markdown]
# # POČETNI PROGRAMSKI KÔD
#
# #### Implementacija AVL stabla

# %%
class BinaryNode:

    # Dodani atributi movie, left_rotations, right_rotations
    def __init__ (self, value = None, movie = None):
        """Create binary node."""
        self.value  = value
        self.left   = None
        self.right  = None
        self.height = 0
        self.movie = movie
        self.left_rotations = 0
        self.right_rotations = 0
        
    def computeHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.height)
        if self.right:
            height = max(height, self.right.height)
            
        self.height = height + 1

    def dynamicHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.dynamicHeight())
        if self.right:
            height = max(height, self.right.dynamicHeight())
            
        return height + 1

    def dynamicHeightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.dynamicHeight()
        if self.right:
            rightTarget = 1 + self.right.dynamicHeight()
            
        return leftTarget - rightTarget

    def heightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.height
        if self.right:
             rightTarget = 1 + self.right.height
                   
        return leftTarget - rightTarget

    def assertAVLProperty (self):
        """Validate AVL property for BST node."""
        if abs(self.dynamicHeightDifference()) > 1:
            return False
        if self.left:
            if not self.left.assertAVLProperty():
                return False
        if self.right:
            if not self.right.assertAVLProperty():
                return False

        return True

    def rotateRight (self):
        """Perform right rotation around given node."""
        newRoot = self.left
        grandson = newRoot.right
        self.left = grandson
        newRoot.right = self

        self.computeHeight()
        
        return newRoot

    def rotateLeft (self):
        """Perform left rotation around given node."""
        newRoot = self.right
        grandson = newRoot.left
        self.right = grandson
        newRoot.left = self
    
        self.computeHeight()
        return newRoot

    def rotateLeftRight (self):
        """Perform left, then right rotation around given node."""
        child = self.left
        newRoot = child.right
        grand1  = newRoot.left
        grand2  = newRoot.right
        child.right = grand1
        self.left = grand2
    
        newRoot.left = child
        newRoot.right = self
    
        child.computeHeight()
        self.computeHeight()
        
        return newRoot

    def rotateRightLeft (self):
        """Perform right, then left rotation around given node."""
        child = self.right
        newRoot = child.left
        grand1  = newRoot.left
        grand2  = newRoot.right
        child.left = grand2
        self.right = grand1
    
        newRoot.left = self
        newRoot.right = child
    
        child.computeHeight()
        self.computeHeight()
      
        return newRoot

    def compareTo (self, value):
        """
        Returns 0 if equal, negative if smaller and positive if greater.
        Suitable for overriding.
        """
        if self.value == value:
            return 0
        if self.value < value:
            return -1
        return +1
    
    # Dodan parametar movie
    def add (self, val, movie):
        """Adds a new node to BST with value and rebalance as needed."""
        newRoot = self

        # if val <= self.value        
        if self.compareTo(val) >= 0:
            self.left = self.addToSubTree (self.left, val, movie)
            if self.heightDifference() == 2:
                #if val <= self.left.value:
                
                if self.left.compareTo(val) >= 0:
                    newRoot = self.rotateRight()
                    self.right_rotations += 1
                else:
                    newRoot = self.rotateLeftRight()
                    self.right_rotations += 1
                    self.left_rotations += 1
        else:
            self.right = self.addToSubTree (self.right, val, movie)
            if self.heightDifference() == -2:
                #if val > self.right.value:
                if self.right.compareTo(val) < 0:
                    newRoot = self.rotateLeft()
                    self.left_rotations += 1
                else:
                    newRoot = self.rotateRightLeft()
                    self.right_rotations += 1
                    self.left_rotations += 1

        newRoot.computeHeight()
        return newRoot

    # Dodan parametar movie
    def newNode (self, val, movie):
        """Return new Binary Node, amenable to subclassing."""
        return BinaryNode(val, movie)

    # Dodan parametar movie
    def addToSubTree (self, parent, val, movie):
        """Add val to parent subtree (if exists) and return root in case it has changed because of rotation."""
        if parent is None:
            return self.newNode(val, movie)
        parent = parent.add(val, movie)
        return parent
           
    def removeFromParent (self, parent, val):
        """Helper method for remove. Ensures proper behavior when removing node that 
        has children."""
        if parent:
            return parent.remove(val)
        return None

    def remove (self, val):
        """
         Remove val from BinaryTree. Works in conjunction with remove
         method in BinaryTree.
        """
        newRoot = self
        rc = self.compareTo(val)
        if rc == 0:
            if self.left is None:
                return self.right

            child = self.left
            while child.right:
                child = child.right
            
            childKey = child.value;
            self.left = self.removeFromParent(self.left, childKey)
            self.value = childKey;

            if self.heightDifference() == -2:
                if self.right.heightDifference() <= 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()
        elif rc > 0:
            self.left = self.removeFromParent(self.left, val)
            if self.heightDifference() == -2:
                if self.right.heightDifference() <= 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()
        else:
            self.right = self.removeFromParent(self.right, val)
            if self.heightDifference() == 2:
                if self.left.heightDifference() >= 0:
                    newRoot = self.rotateRight()
                else:
                    newRoot = self.rotateLeftRight()

        newRoot.computeHeight()
        return newRoot

    def __repr__ (self):
        """Useful debugging function to produce linear tree representation."""
        leftS = ''
        rightS = ''
        if self.left:
            leftS = str(self.left)
        if self.right:
            rightS = str(self.right)
        return "(L:" + leftS + " " + str(self.value) + " R:" + rightS + ")"

    def inorder (self):
        """In order traversal generator of tree rooted at given node."""
        if self.left:
            for n in self.left.inorder():
                yield n

        yield self.value

        if self.right:
            for n in self.right.inorder():
                yield n

class BinaryTree:

    def __init__ (self):
        """Create empty binary tree."""
        self.root = None

    def __repr__ (self):
        if self.root is None:
            return "avl:()"
        return "avl:" + str(self.root)
    
    # Dodan parametar movie
    def newNode (self, value, movie):
        """Return new BinaryNode object. Suitable for overriding."""
        return BinaryNode(value, movie)
    
    # Dodan parametar movie
    def add (self, value, movie):
        """Insert value into proper location in Binary Tree."""
        if self.root is None:
            self.root = self.newNode(value, movie)
        else:
            self.root = self.root.add(value, movie)

    def __contains__ (self, target):
        """Check whether BST contains target value."""
        node = self.root
        while node:
            rc = node.compareTo(target)
            if rc > 0:
                node = node.left
            elif rc < 0:
                node = node.right
            else:
                return True
        return False
     
    def remove (self, val):
        """Remove value from tree."""
        if self.root:
            self.root = self.root.remove(val)

    def __iter__ (self):          # definira iteriranje kroz inorder ispis
        """In order traversal of elements in the tree."""
        if self.root:
            return self.root.inorder()
                        
    def assertAVLProperty (self):
        """Validate AVL property for BST Tree."""
        if self.root:
            return self.root.assertAVLProperty()
        else:
            return True

# %% [markdown]
# #### Implementacija razreda MoviesData

# %%
class MoviesData:

    def __init__(self, id, short_name, long_name):
        self.id = id
        self.short_name = short_name
        self.long_name = long_name

    def __str__(self) -> str:
        return f'{self.id} | {self.short_name} | {self.long_name}'

def extract_rows() -> None:
    # redovi 185297-200296, 387649-402648
    file1 = open('movie.txt', "r")

    my_rows = []

    for idx, row in enumerate(file1.readlines()):

        if idx >= 185297 and idx <= 200296 or idx >= 387649 and idx <= 402648:
            my_rows.append(row)

    file2 = open("movie09.txt", "w")
    file2.writelines(my_rows)

def convert_row_to_movie(row: str) -> MoviesData:
    movie_list = row.split("\t")
    movie_list[-1] = movie_list[-1].strip()
    movie_list[1] = movie_list[1].rstrip()
    movie_list[1] = movie_list[1].lstrip()
    movie_obj = MoviesData(*movie_list)
    return movie_obj

def get_movies_from_file() -> list[MoviesData]:
    file = open('movie09.txt', 'r')
    movies = [convert_row_to_movie(row) for row in file.readlines()]
    return movies

# %% [markdown]
# # IMPLEMENTACIJA ISPITNOG KODA SUKLADNO ZADACIMA

# %% [markdown]
# a) Na temelju sadržaja tekstualne datoteke treba izgraditi AVL stablo uporabom razreda *BinaryTree* temeljem kraćeg naziva filma kao indeksnog ključa. Ispisati visinu dobivenog AVL stabla.

# %%
#extract_rows()

myTree = BinaryTree() 

movies = get_movies_from_file()
    
for m in movies:
    myTree.add(m.short_name, m)

print(f'Visina: {myTree.root.height}')
# Out:
# Visina: 17

# %% [markdown]
# b) Implementirati pretraživanje podataka o filmu uporabom implementiranog indeksa i to tako da se za traženje može zadati kraći naziv filma cjelovito ili djelomično u obliku prefiksa korištenjem znaka '\*'. Primjerice, može se unijeti cjeloviti naziv 'Bugsy' ili samo dio odnosno prefiks naziva 'Bug*'. Nakon što je podatak pronađen treba ispisati cijeli zapis: ID, kraći naziv, duži naziv.

# %%
import re

def search_keys(root: BinaryNode, pattern: str) -> list[MoviesData]:
        
        matches = []

        if "*" in pattern:
            pattern = list(pattern)
            pattern[-1] = "."
            pattern.append("*")
            pattern = "".join(pattern)
        
        regex = re.compile(pattern)

        find_matching_keys_recursive(root, regex, matches)
        return matches

def find_matching_keys_recursive(node: BinaryNode, regex: re.Pattern, matches: list) -> None:

    if node is not None:

        if regex.fullmatch(node.value):
            matches.append(node.movie)
            
        find_matching_keys_recursive(node.left, regex, matches)
        find_matching_keys_recursive(node.right, regex, matches)

find1 = "The End"

rez = search_keys(myTree.root, find1)
for i in rez:
    print(i)

find2 = "Country Girls*"

rez = search_keys(myTree.root, find2)
for i in rez:
    print(i)
# Out:
# 497625 | The End | The End  (1996)
# 1902342 | Country Girls in Heat | Country Girls in Heat
# 1902343 | Country Girls in Heat 2 | Country Girls in Heat 2

# %% [markdown]
# c) Implementirati funkciju za traženje u rangu npr. sve filmove od 'Pick*' do 'Ten*', ili od 'F*' do 'M*'. Rangove treba moći zadati proizvoljno.

# %%
def search_keys_in_range(root: BinaryNode, start: str, end: str) -> list[MoviesData]:

    if "*" in start:
        start = list(start)
        start[-1] = "."
        start.append("*")
        start = "".join(start)

    if "*" in end:
        end = list(end)
        end[-1] = "."
        end.append("*")
        end = "".join(end)

    matches = []

    regex1 = re.compile(start)
    regex2 = re.compile(end)
    
    def search_keys_in_range_recursive(node: BinaryNode) -> None:

        if node is None:
            return
        
        if node.value > start:
            search_keys_in_range_recursive(node.left)

        if (start <= node.value <= end and regex1.fullmatch(node.value) or
            start <= node.value <= end and regex2.fullmatch(node.value) or
            start <= node.value <= end):
            matches.append(node.movie)

        if node.value < end:
            search_keys_in_range_recursive(node.right)
    
    search_keys_in_range_recursive(root)
    return matches

p1 = "Pick*"
p2 = "Ten*"

rez = search_keys_in_range(myTree.root, p1, p2)
for i in rez:
    print(i)
# Out:
# 501570 | Pickersgill People | Pickersgill People
# 1938416 | Picking Miss Octane | Picking Miss Octane
# 1953987 | Pickles for Nickels | Pickles for Nickels
# 501501 | Picknick | Picknick
# 48890 | Pickup on 101 | Pickup on 101
# 505495 | Picnic Stops | Picnic Stops
# 480410 | Picnic at Hanging Rock | Picnic at Hanging Rock
# 1982210 | Picture Claire | Picture Claire  (2001)
# 494513 | Picture Mommy Dead | Picture Mommy Dead  (1966)
# 507547 | Picture People No. 1: Stars in Defense | Picture People No. 1: Stars in Defense
# 507548 | Picture People No. 2: Hollywood Sports | Picture People No. 2: Hollywood Sports
# 198773 | Picture Snatcher | Picture Snatcher
# 487160 | Picture of Light | Picture of Light  (1994)
# 499578 | PicturePages | PicturePages
# 193138 | Pidey | Pidey  (2006)
# 50512 | Pido Dida 3: May kambal na | Pido Dida 3: May kambal na
# 491608 | Pie Eating 101: 101 Years of Pie | Pie Eating 101: 101 Years of Pie  (2001)
# 484728 | PieNegro | PieNegro  (2006)
# 480886 | Pieces of Peace | Pieces of Peace  (2010)
# 480884 | Pieces of Peace | Pieces of Peace
# 496965 | Pieces of a Memory | Pieces of a Memory
# 502399 | Pieces of the Game | Pieces of the Game
# 50927 | Piedras | Piedras
# 50841 | Piel canela | Piel canela
# 1984 | Pieri - militsiis tanamshromeli | Pieri - militsiis tanamshromeli
# 506335 | Pierre Brissac, the Brazen | Pierre Brissac, the Brazen
# 49225 | Pierre Fatumbi Verger: Mensageiro Entre Dois Mundos | Pierre Fatumbi Verger: Mensageiro Entre Dois Mundos  (2000)
# 1996907 | Pierre Lefvre on Acting | Pierre Lefvre on Acting
# 500815 | Pierre Schoendoerffer, la sentinelle de la mmoire | Pierre Schoendoerffer, la sentinelle de la mmoire
# 2001182 | Pierre and Gilles, Love Stories | Pierre and Gilles, Love Stories  (1997)
# 192603 | Pierre et Jean | Pierre et Jean
# 481512 | Pierrette ne fa una delle sue | Pierrette ne fa una delle sue
# 507942 | Pig Tails in a Blanket | Pig Tails in a Blanket  (2010)
# 507322 | Pige pour une fille seule | Pige pour une fille seule
# 1977080 | Pigen som ville ned p jorden | Pigen som ville ned p jorden  (2007)
# 1905805 | Pigeonholed | Pigeonholed  (1999)
# 1994241 | Piges | Piges  (1939)
# 490449 | Pigskin | Pigskin  (2009)
# 485936 | Pigskin | Pigskin
# 489781 | Pigsy Doodle | Pigsy Doodle
# 192750 | Piksele | Piksele  (2010)
# 484881 | Piktura Ammak | Piktura Ammak
# 497238 | Pila-balde | Pila-balde
# 192732 | Pilkarski poker | Pilkarski poker
# 486637 | Pillars of the Sky | Pillars of the Sky  (1956)
# 1980071 | Pilz | Pilz
# 488473 | Pim Pandoer in het nauw | Pim Pandoer in het nauw
# 1955165 | Pimple's The Whip | Pimple's The Whip  (1917)
# 1923247 | Pimps | Pimps  (1997)
# 1943569 | Pin Up Club | Pin Up Club
# 200381 | Pinagbiyak na bunga | Pinagbiyak na bunga
# 200302 | Pinakamagandang hayop sa daigdig | Pinakamagandang hayop sa daigdig
# 1922326 | Pinata Head | Pinata Head
# 478272 | Pineapple | Pineapple
# 490030 | Pineapple Express | Pineapple Express  (2008)
# 502659 | Pink Cowboy Boots | Pink Cowboy Boots  (2005)
# 200182 | Pink Floyd London '66-'67 | Pink Floyd London '66-'67  (1967)
# 1956120 | Pink Gang | Pink Gang  (2010)
# 488334 | Pink Glasses | Pink Glasses
# 505413 | Pink Gods | Pink Gods
# 505339 | Pink Motel | Pink Motel
# 1941237 | Pink Octopus | Pink Octopus
# 19723 | Pink Punk | Pink Punk
# 1909190 | Pink Pyjamas | Pink Pyjamas  (2001)
# 1956121 | Pink Saris | Pink Saris
# 491485 | Pinkie | Pinkie
# 507556 | Pinko's Place | Pinko's Place
# 481114 | Pinocchio i Hollywood | Pinocchio i Hollywood  (1998)
# 484626 | Pinoy Scout | Pinoy Scout
# 198327 | Pins | Pins
# 197413 | Pintor e Modelo | Pintor e Modelo
# 478971 | Pinulot ka lang sa lupa | Pinulot ka lang sa lupa
# 1999300 | Pinulot ka lang sa lupa | Pinulot ka lang sa lupa  (1987)
# 499579 | Pinwheel | Pinwheel
# 1956019 | Pioli Phukan | Pioli Phukan  (1955)
# 2001193 | Pioneer House | Pioneer House
# 191344 | Pioneer Marshal | Pioneer Marshal
# 503924 | Pioneer Scout | Pioneer Scout
# 494060 | Pipe Rock Goes Wild | Pipe Rock Goes Wild
# 477201 | Pipeline | Pipeline
# 489664 | Pipes of Peace | Pipes of Peace
# 1989009 | Pippi Lngstrump | Pippi Lngstrump  (1949)
# 193717 | Pippin Up to His Pranks | Pippin Up to His Pranks
# 477894 | Piraeus | Piraeus  (2005)
# 196603 | Piranha | Piranha  (2010)
# 190401 | Piranha | Piranha
# 194252 | Piraten auf der Pferdeinsel | Piraten auf der Pferdeinsel  (1963)
# 495082 | Pirates | Pirates  (1998)
# 508354 | Pirates VS Ninjas | Pirates VS Ninjas  (2011)
# 50873 | Pirates of the Caribbean: At World's End | Pirates of the Caribbean: At World's End  (2007)
# 478311 | Pirates of the Caribbean: Dead Man's Chest | Pirates of the Caribbean: Dead Man's Chest  (2006)
# 191345 | Pirates of the Prairie | Pirates of the Prairie
# 480853 | Pirates: Quest for Snake Island | Pirates: Quest for Snake Island
# 1985 | Pirosmani | Pirosmani
# 1986 | Pirveli mertskhali | Pirveli mertskhali
# 198654 | Pisay | Pisay
# 1936358 | Pisi pisi | Pisi pisi  (1975)
# 199488 | Pismo do Amerika | Pismo do Amerika  (2001)
# 1915283 | Piso de soltero | Piso de soltero  (1964)
# 492925 | Piss | Piss
# 509805 | Piss Pants | Piss Pants
# 1929538 | Pissing Vocal Gold | Pissing Vocal Gold
# 49571 | Pitch Perfect | Pitch Perfect  (2005)
# 1924859 | Pitchin' In | Pitchin' In  (2010)
# 198070 | Pitfall | Pitfall
# 50698 | Pitik bulag | Pitik bulag
# 494464 | Pitrats | Pitrats  (2010)
# 19860 | Pitter Patter | Pitter Patter
# 191931 | Pittsville - Ein Safe voll Blut | Pittsville - Ein Safe voll Blut
# 484080 | Pituco | Pituco
# 484679 | Piu che la vita  l'amore... | Piu che la vita  l'amore...
# 506026 | Pivot Point | Pivot Point  (2011)
# 479170 | Pizza Maffia | Pizza Maffia
# 1904115 | Pizza Morgana | Pizza Morgana
# 194461 | Pizza noir | Pizza noir
# 497603 | Pjaros prohibidos | Pjaros prohibidos
# 479139 | Pjevam danju, pjevam nocu | Pjevam danju, pjevam nocu
# 484352 | Place of Weeping | Place of Weeping
# 487084 | Plainsclothes Man | Plainsclothes Man
# 191346 | Plainsman and the Lady | Plainsman and the Lady
# 1932978 | Plan 9 from Syracuse | Plan 9 from Syracuse
# 497758 | Plancie Herica | Plancie Herica
# 48270 | Plane Nuts | Plane Nuts
# 1926387 | Planet Danmark | Planet Danmark
# 2000538 | Planet H2O | Planet H2O
# 481886 | Planet U.N. | Planet U.N.  (2009)
# 199511 | Planeta Desconocido | Planeta Desconocido  (2011)
# 19966 | Planetfall | Planetfall  (2005)
# 49312 | Planta 4 | Planta 4
# 493673 | Plantage Tamarinde | Plantage Tamarinde  (1964)
# 190239 | Planto de Notcias | Planto de Notcias  (1999)
# 489417 | Plastic Bitch | Plastic Bitch  (2005)
# 498038 | Plastic Heart | Plastic Heart  (2011)
# 1977702 | Plastic Horses | Plastic Horses
# 19581 | Plastic Surgery: Before & After | Plastic Surgery: Before & After
# 1915779 | Plastics | Plastics
# 1948223 | Plate-Smashing Gary Presents: GimmeGimme Cigs | Plate-Smashing Gary Presents: GimmeGimme Cigs
# 1948224 | Plate-Smashing Gary Presents: GimmeGimme Gatorade | Plate-Smashing Gary Presents: GimmeGimme Gatorade
# 1948225 | Plate-Smashing Gary Presents: GimmeGimme Tater Tots | Plate-Smashing Gary Presents: GimmeGimme Tater Tots
# 506842 | Plateaus | Plateaus
# 50726 | Plates | Plates  (2008)
# 493494 | Platform 4 | Platform 4
# 1952922 | Platform 4 | Platform 4  (2007)
# 1982444 | Plumitas calientes | Plumitas calientes  (1994)
# 477260 | Plunge | Plunge  (2000)
# 1914808 | Plurielles | Plurielles  (1979)
# 1946253 | Plus de whisky pour Callaghan! | Plus de whisky pour Callaghan!  (1955)
# 2005938 | Plushy | Plushy  (2005)
# 193691 | Pluto | Pluto
# 482893 | Pluto Junior | Pluto Junior
# 482890 | Pluto and the Armadillo | Pluto and the Armadillo
# 482891 | Pluto and the Gopher | Pluto and the Gopher
# 482892 | Pluto at the Zoo | Pluto at the Zoo
# 482894 | Pluto's Christmas Tree | Pluto's Christmas Tree
# 482895 | Pluto's Fledgling | Pluto's Fledgling
# 482896 | Pluto's Heart Throb | Pluto's Heart Throb
# 482897 | Pluto's Housewarming | Pluto's Housewarming
# 482898 | Pluto's Kid Brother | Pluto's Kid Brother
# 482899 | Pluto's Party | Pluto's Party
# 482900 | Pluto's Purchase | Pluto's Purchase
# 482901 | Pluto's Quin-puplets | Pluto's Quin-puplets
# 482902 | Pluto's Surprise Package | Pluto's Surprise Package
# 482903 | Pluto's Sweater | Pluto's Sweater
# 2001030 | Pneurosis | Pneurosis
# 48467 | Po de Acar | Po de Acar
# 479477 | Poble Nou | Poble Nou
# 499153 | Pod isto nebo | Pod isto nebo
# 1998784 | Podijum | Podijum  (2002)
# 1996872 | Podzhigateli | Podzhigateli  (1988)
# 192391 | Podzimn nvrat | Podzimn nvrat
# 489584 | Poem | Poem
# 1926611 | Poem 8 | Poem 8
# 500867 | Poemi asolani | Poemi asolani  (1985)
# 482004 | Poets on Film No. 1 | Poets on Film No. 1  (1977)
# 190939 | Poezd chrezvychaynogo naznacheniya | Poezd chrezvychaynogo naznacheniya
# 1926052 | Pogled kroz prozor | Pogled kroz prozor
# 191989 | Point B | Point B
# 2004632 | Point Five | Point Five
# 488927 | Point of Betrayal | Point of Betrayal  (1995)
# 48271 | Pointed Heels | Pointed Heels
# 1910130 | Poison Pen | Poison Pen  (1939)
# 1905274 | Pok hoh ka fe | Pok hoh ka fe
# 1987 | Pokhishcheniye veka | Pokhishcheniye veka
# 192733 | Pokj z widokiem na morze | Pokj z widokiem na morze
# 192402 | Poklad byzantskho kupce | Poklad byzantskho kupce  (1967)
# 498528 | Pokmon | Pokmon  (1998)
# 194061 | Polar Bear | Polar Bear  (2009)
# 481058 | Polar Perils | Polar Perils
# 482904 | Polar Trappers | Polar Trappers
# 199937 | Poldark | Poldark
# 1929817 | Poldark | Poldark  (1975)
# 1934263 | Poldis Engel | Poldis Engel
# 487509 | Pole Riders | Pole Riders  (2011)
# 1980189 | Polenta | Polenta  (1982)
# 491504 | Poles Apart | Poles Apart
# 199397 | Polica judicial federal | Polica judicial federal
# 196940 | Police 2020 | Police 2020
# 195384 | Police Quest III: The Kindred | Police Quest III: The Kindred
# 198909 | Police mondaine | Police mondaine
# 1908351 | Police mondaine | Police mondaine  (1937)
# 194236 | Poligon-1 | Poligon-1
# 191140 | Polis Paulus' pskasmll | Polis Paulus' pskasmll
# 500157 | Politeness Pays | Politeness Pays
# 493600 | Politica zero | Politica zero
# 493662 | Political Animals | Political Animals
# 499771 | Possum Paddock | Possum Paddock
# 2000194 | Post It | Post It
# 495233 | Post-It | Post-It
# 500516 | Postmortem | Postmortem  (2005)
# 509708 | Postpartum | Postpartum  (2007)
# 199768 | Pot Luck | Pot Luck
# 502356 | Pot o' Gold | Pot o' Gold  (1941)
# 494915 | Potencia para el desarrollo | Potencia para el desarrollo
# 192760 | Poteryavshye solntse | Poteryavshye solntse
# 477377 | Potion d'amour | Potion d'amour
# 196129 | Potomok Chingis-Khana | Potomok Chingis-Khana
# 1911 | Potop | Potop
# 1984638 | Potrazi Vandu Kos | Potrazi Vandu Kos  (1957)
# 1919361 | Poucette ou le plus jeune dtective du monde - pisode 1: En plein mystre | Poucette ou le plus jeune dtective du monde - pisode 1: En plein mystre  (1920)
# 1903552 | Pouic-Pouic | Pouic-Pouic  (1963)
# 501587 | Poulet cocotte | Poulet cocotte  (2003)
# 481336 | Pouncer | Pouncer
# 490938 | Pound Puppies | Pound Puppies
# 1919759 | Pour Maman,  lire si je me rveille pas... | Pour Maman,  lire si je me rveille pas...
# 1911151 | Pour aimer, encore | Pour aimer, encore  (2010)
# 490144 | Pour chaque non | Pour chaque non  (2005)
# 1972353 | Pour fter Rosalie | Pour fter Rosalie
# 1991967 | Pour se faire pouser | Pour se faire pouser
# 479475 | Pourquoi pas moi? | Pourquoi pas moi?
# 1953179 | Pourquoi toi et pas moi? | Pourquoi toi et pas moi?
# 191842 | Poussire de diamant | Poussire de diamant
# 1957504 | Povera Leda... | Povera Leda...
# 191348 | Powder River Rustlers | Powder River Rustlers
# 194457 | Powderburn | Powderburn  (1999)
# 477631 | Power Factory Featuring C+C Music Factory | Power Factory Featuring C+C Music Factory  (1992)
# 1926882 | Power Rangers Samurai | Power Rangers Samurai
# 493320 | Power Rangers Time Force | Power Rangers Time Force
# 194353 | Powerless | Powerless
# 1902743 | Powiedz to, Gabi | Powiedz to, Gabi  (2003)
# 1912 | Powroty | Powroty
# 190940 | Poyezd vne raspisaniya | Poyezd vne raspisaniya
# 49573 | Pozabljeni zaklad | Pozabljeni zaklad
# 1955990 | Pozhudhu Vidinjaachchu | Pozhudhu Vidinjaachchu
# 199064 | Pra Frente, Brasil | Pra Frente, Brasil
# 198227 | Practical Guide to Belgrade with Singing and Crying | Practical Guide to Belgrade with Singing and Crying
# 190463 | Practice Tee | Practice Tee  (1949)
# 1956054 | Prahlad | Prahlad
# 1955991 | Praja Rajyam | Praja Rajyam
# 479183 | Praline | Praline  (2007)
# 194533 | Pram | Pram  (2010)
# 1936580 | Pratos combinados | Pratos combinados
# 484171 | Prayers of Desperation | Prayers of Desperation  (2005)
# 200255 | Pre et fils | Pre et fils
# 488235 | Prea cald pentru luna mai | Prea cald pentru luna mai
# 50046 | Prea mic pentru un razboi att de mare | Prea mic pentru un razboi att de mare
# 49189 | Prea trziu | Prea trziu
# 5030 | Preacher's Kid | Preacher's Kid
# 19589 | Precious | Precious
# 1942 | Predator 2 | Predator 2
# 1993967 | Predileo | Predileo  (2009)
# 195443 | Predisposed | Predisposed  (2012)
# 502083 | Prime of Your Life | Prime of Your Life  (2010)
# 491525 | PrimeMates | PrimeMates  (2010)
# 490210 | Primer | Primer
# 494916 | Primer Festival de Mortadelo y Filemn, agencia de informacin | Primer Festival de Mortadelo y Filemn, agencia de informacin
# 504471 | Primer movimiento para veinte hombres en un cuarto vaco | Primer movimiento para veinte hombres en un cuarto vaco
# 476824 | Primirje | Primirje
# 2006486 | Primitifs | Primitifs  (2002)
# 482908 | Primitive Pluto | Primitive Pluto
# 19098 | Primrose Path | Primrose Path
# 47729 | Princ, a katona | Princ, a katona
# 1956078 | Prince Thaksen | Prince Thaksen
# 1954048 | Prince embt par Rigadin | Prince embt par Rigadin  (1920)
# 49556 | Prince of Persia | Prince of Persia
# 200013 | Prince of Persia 3D | Prince of Persia 3D  (1999)
# 200597 | Prince of Pirates | Prince of Pirates
# 2006446 | Prince of Players | Prince of Players  (1955)
# 1940408 | Prince of the Plains | Prince of the Plains  (1949)
# 1939937 | Princess Scargo and the Birthday Pumpkin | Princess Scargo and the Birthday Pumpkin
# 506227 | Principals | Principals
# 1933916 | Principessina | Principessina  (1943)
# 494980 | Prins Piwi | Prins Piwi  (1974)
# 498566 | Prinsipe Villarba | Prinsipe Villarba
# 50047 | Printre colinele verzi | Printre colinele verzi
# 193087 | Printsipyalnyy i zhalostlivyy vzglyad | Printsipyalnyy i zhalostlivyy vzglyad
# 499523 | Prisin de la Conciencia | Prisin de la Conciencia  (2010)
# 488096 | Prisioneiro de um Sonho | Prisioneiro de um Sonho
# 200369 | Prisionero en la ciudad | Prisionero en la ciudad
# 1917526 | Prison Babies | Prison Babies  (1973)
# 191349 | Prison Break | Prison Break
# 503235 | Prison Breaker | Prison Breaker  (1936)
# 1958799 | Prison Girls | Prison Girls  (1972)
# 492292 | Prison Planet | Prison Planet  (1992)
# 1915631 | Prison Warden | Prison Warden  (1949)
# 195295 | Prison Without Bars | Prison Without Bars
# 1961778 | Prison World | Prison World
# 478143 | Prisoner of Zenda | Prisoner of Zenda
# 191350 | Prisoners in Petticoats | Prisoners in Petticoats
# 484280 | Prisoners of the Storm | Prisoners of the Storm
# 508743 | Priv de vieillesse | Priv de vieillesse
# 47937 | Private Benjamin | Private Benjamin
# 196512 | Private Benjamin | Private Benjamin  (1980)
# 1959772 | Private Eye's, Public Display | Private Eye's, Public Display
# 1978529 | Private Function | Private Function
# 1971863 | Private Hell 36 | Private Hell 36  (1954)
# 500511 | Private Hunting Grounds | Private Hunting Grounds
# 19727 | Private Moments | Private Moments
# 50909 | Private Nights | Private Nights
# 1963212 | Private Number | Private Number  (1936)
# 482909 | Private Pluto | Private Pluto
# 478927 | Private Potter | Private Potter
# 501386 | Private Practice | Private Practice
# 200439 | Private Romeo | Private Romeo  (2011)
# 503760 | Private Stars | Private Stars
# 1981551 | Private Sun | Private Sun  (2011)
# 196234 | Privateer | Privateer  (2009)
# 50458 | Pro BMX 2 | Pro BMX 2  (2002)
# 19728 | Pro-Ball Cheerleaders | Pro-Ball Cheerleaders
# 1912061 | Pro-trusion | Pro-trusion  (2011)
# 508607 | Probed | Probed
# 479834 | Proceeding with Harmful Effects | Proceeding with Harmful Effects  (2011)
# 1934747 | Processing Days | Processing Days
# 191600 | Processo al generale Baratieri per la sconfitta di Adua | Processo al generale Baratieri per la sconfitta di Adua
# 480421 | Processo delle zitelle | Processo delle zitelle
# 191873 | Prodigal Daughters | Prodigal Daughters  (2005)
# 484383 | Prodigy | Prodigy  (2001)
# 196450 | Producing the Hood | Producing the Hood  (2008)
# 1990182 | Product Placement | Product Placement
# 492029 | Production | Production
# 1980227 | Profane | Profane
# 195929 | Profane Language | Profane Language
# 191932 | Profesor Wilczur | Profesor Wilczur
# 480507 | Professor Majiga | Professor Majiga  (2010)
# 482119 | Profilaxis | Profilaxis
# 506910 | Profondo Rosso: From Celluloid to Shop | Profondo Rosso: From Celluloid to Shop
# 2007123 | Profundo carmes | Profundo carmes  (1996)
# 492432 | Prognosis | Prognosis
# 502115 | Programmable Dreams | Programmable Dreams  (2007)
# 496178 | Programmed to Kill | Programmed to Kill  (1987)
# 484325 | Prohibido para menores | Prohibido para menores
# 1921814 | Proibido Sonhar | Proibido Sonhar  (1944)
# 479215 | Proie | Proie
# 506094 | Project Catwalk | Project Catwalk  (2006)
# 485989 | Project Nine | Project Nine
# 191241 | Project Nine | Project Nine  (2010)
# 192653 | Project Projection | Project Projection
# 47741 | Project Shadowchaser II | Project Shadowchaser II  (1994)
# 477979 | Project SnoFighter | Project SnoFighter  (2011)
# 487055 | Project Z-6463 | Project Z-6463
# 2004281 | Project: Comic-Con | Project: Comic-Con  (2010)
# 194580 | Project: Valkyrie | Project: Valkyrie  (2002)
# 1936347 | Projekci | Projekci
# 1956220 | Promenades d't | Promenades d't  (1992)
# 1992311 | Promessas de Amor | Promessas de Amor
# 476825 | Prometej s otoka Visevice | Prometej s otoka Visevice
# 478571 | Prometheus and the Butcher | Prometheus and the Butcher
# 479799 | Promis, jur | Promis, jur
# 199056 | Promise and Unrest | Promise and Unrest  (2010)
# 491710 | Promised Land of Heavy Metal | Promised Land of Heavy Metal
# 1992049 | Promises Kept | Promises Kept  (2008)
# 484680 | Promozione per... meriti personali | Promozione per... meriti personali
# 199009 | Promthe aujourd'hui dans le Treizime | Promthe aujourd'hui dans le Treizime
# 198711 | Promthe aujourd'hui dans le Treizime | Promthe aujourd'hui dans le Treizime  (1991)
# 1995923 | Pronobis | Pronobis  (2003)
# 199517 | Pronobis | Pronobis
# 191645 | Pronstic reservat | Pronstic reservat
# 194956 | Pronto chi parla? | Pronto chi parla?
# 480834 | Proof of Chaos | Proof of Chaos
# 495381 | Proof or Propaganda | Proof or Propaganda  (2008)
# 192138 | Proolissa | Proolissa
# 1912684 | Prop 8: The Web Series | Prop 8: The Web Series  (2009)
# 1964283 | Prop's Angel | Prop's Angel  (1913)
# 478508 | Propheteering | Propheteering
# 499354 | Propiedad horizontal | Propiedad horizontal
# 479613 | Prostitution | Prostitution
# 192067 | Prota | Prota
# 192068 | Prota II ou Prota et l'auto infernale | Prota II ou Prota et l'auto infernale
# 192069 | Prota III ou La course  la mort | Prota III ou La course  la mort
# 496646 | Pumping Iron | Pumping Iron  (1977)
# 198443 | Pumpkin Boy | Pumpkin Boy
# 2002536 | Punch Me in the Stomach | Punch Me in the Stomach
# 192582 | Punchbug | Punchbug  (2010)
# 19596 | Punchcard Player | Punchcard Player
# 19447 | Punching the Clown | Punching the Clown
# 50048 | Punct si de la capat | Punct si de la capat
# 49190 | Punctul zero | Punctul zero
# 1996573 | Punjab Mail | Punjab Mail
# 199840 | Punk Like Me | Punk Like Me
# 200220 | Punk Strut: The Movie | Punk Strut: The Movie  (2010)
# 498650 | Punkshakes | Punkshakes  (2008)
# 1989017 | Punkt 12 | Punkt 12  (1992)
# 506550 | Punky, Take Your Shirt Off! | Punky, Take Your Shirt Off!
# 1989532 | Punta Escarlata | Punta Escarlata
# 506766 | Puntos suspensivos o Esperando a los brbaros | Puntos suspensivos o Esperando a los brbaros
# 503453 | Puppet Show | Puppet Show  (2011)
# 489757 | Pups | Pups
# 197632 | Pups | Pups  (1999)
# 498250 | Pur week-end | Pur week-end  (2007)
# 479399 | Pura coincidencia | Pura coincidencia
# 1995439 | Puraskar | Puraskar  (1970)
# 503288 | Purdie & Pepper | Purdie & Pepper
# 503289 | Purdie Wars: A Few Dopes | Purdie Wars: A Few Dopes
# 196702 | Purdie and the Beefcake Burnout | Purdie and the Beefcake Burnout
# 507212 | Pure Evil | Pure Evil  (2011)
# 19534 | Pure Race | Pure Race
# 1971026 | Purgatoire | Purgatoire  (2001)
# 1963210 | Purple Flowers | Purple Flowers  (2010)
# 1907983 | Push Pull | Push Pull  (2009)
# 487988 | Pushing 23 | Pushing 23  (2009)
# 200457 | Pushing Up Daisies | Pushing Up Daisies
# 49403 | Pushing the Envelope | Pushing the Envelope  (2001)
# 496494 | Puss & kram | Puss & kram  (1967)
# 482911 | Puss Cafe | Puss Cafe
# 1983444 | Pussy | Pussy
# 509101 | Pussy Galore | Pussy Galore  (1965)
# 1947195 | Pussy da Red Nosed Reindeer | Pussy da Red Nosed Reindeer  (2000)
# 504934 | Pussy on a Hot Tin Roof | Pussy on a Hot Tin Roof
# 477319 | Put 'Em Up | Put 'Em Up
# 478612 | Put Me Off at Wayville | Put Me Off at Wayville
# 494386 | Put na mjesec | Put na mjesec  (1998)
# 1987292 | Put, vejini | Put, vejini  (1973)
# 496947 | Putapela | Putapela
# 50049 | Puterea si adevarul | Puterea si adevarul
# 1902308 | Puthran | Puthran
# 1912672 | Putting It On | Putting It On
# 501140 | Putting the River in Reverse | Putting the River in Reverse
# 47750 | Putz | Putz
# 193088 | Pyat minut strakha | Pyat minut strakha
# 1931563 | Pygmalion et Galathe | Pygmalion et Galathe
# 507949 | Pyramid | Pyramid
# 196606 | Pyramid Highway | Pyramid Highway
# 1988 | Qalaqi Anara | Qalaqi Anara
# 1928652 | Qing shui wan, dan shui wan | Qing shui wan, dan shui wan
# 1999735 | Qu crees? | Qu crees?
# 193048 | Qu gozada de divorcio! | Qu gozada de divorcio!
# 1987814 | Qu hago con la criatura? | Qu hago con la criatura?  (1936)
# 498840 | Qu locura! | Qu locura!
# 1987978 | Qu mujeres! | Qu mujeres!
# 1919944 | Qu quiere la banda | Qu quiere la banda
# 199179 | Qu verde era mi padre! | Qu verde era mi padre!
# 1989577 | Qu' est-ce q' cest | Qu' est-ce q' cest
# 503506 | Qu'est-ce qu'on attend pour tre heureux! | Qu'est-ce qu'on attend pour tre heureux!  (1982)
# 191902 | Qu'il est joli garon l'assassin de papa | Qu'il est joli garon l'assassin de papa
# 190601 | Qu'un seul tienne et les autres suivront | Qu'un seul tienne et les autres suivront
# 488609 | Quadrilha | Quadrilha
# 1926702 | Quadrophenia | Quadrophenia  (1979)
# 1984391 | Quai de Grenelle | Quai de Grenelle  (1950)
# 480119 | Quak | Quak
# 1947668 | Qualquer Gato Vira-Lata | Qualquer Gato Vira-Lata  (2011)
# 483357 | Quand j'tais chanteur | Quand j'tais chanteur  (2006)
# 1914648 | Quand j'tais gothique | Quand j'tais gothique  (2011)
# 1937584 | Quand la femme s'en mle | Quand la femme s'en mle  (1957)
# 1926 | Quand le soleil meurt | Quand le soleil meurt
# 1914147 | Quand le vent tisse les fleurs | Quand le vent tisse les fleurs  (2003)
# 479205 | Quand les feuilles tomberont | Quand les feuilles tomberont
# 1975338 | Quand maman sera partie | Quand maman sera partie  (2009)
# 193927 | Quand tu veux | Quand tu veux  (2008)
# 1946425 | Quando o Inverno Chega | Quando o Inverno Chega
# 497654 | Quando os Campos Florescem | Quando os Campos Florescem
# 20062 | Quantum Leap: A Leap to Di for | Quantum Leap: A Leap to Di for
# 49719 | Quantum of Solace | Quantum of Solace  (2008)
# 194957 | Quartetto pazzo | Quartetto pazzo
# 480817 | Quartier de femmes | Quartier de femmes  (1974)
# 508262 | Quatermass and the Pit | Quatermass and the Pit  (1967)
# 197962 | Quatre heures du matin | Quatre heures du matin
# 1913459 | Quatre lments: Terre | Quatre lments: Terre  (1999)
# 483321 | Quatre toiles | Quatre toiles  (2006)
# 1964532 | Quatro Paredes Nuas | Quatro Paredes Nuas
# 500897 | Quattro rose rosse | Quattro rose rosse
# 1936985 | Quattro rose rosse | Quattro rose rosse  (1951)
# 500622 | Que Horas So? | Que Horas So?
# 1958407 | Que buena TV | Que buena TV
# 500410 | Que haremos con pap? | Que haremos con pap?
# 482324 | Que la force soit avec Raoul | Que la force soit avec Raoul  (2005)
# 488976 | Que padre tan padre! | Que padre tan padre!
# 500123 | Que viene mi marido! | Que viene mi marido!
# 197812 | Que viva Mexico! | Que viva Mexico!  (1932)
# 198958 | Que viva Mxico | Que viva Mxico
# 496041 | Quebec, Quebec | Quebec, Quebec
# 1982596 | Queen Down | Queen Down  (2004)
# 196759 | Queen of Broadway | Queen of Broadway
# 1919364 | Queen of Cactus Cove | Queen of Cactus Cove  (2005)
# 1968807 | Queen of Outer Space | Queen of Outer Space  (1958)
# 1947146 | Queen of the Blues | Queen of the Blues  (1979)
# 485995 | Queen of the Mob | Queen of the Mob  (1940)
# 497349 | Queens Are Trumps | Queens Are Trumps
# 1982991 | Queens of the Air | Queens of the Air  (1938)
# 491421 | Queensbury Rules | Queensbury Rules  (2011)
# 196657 | Queensbury Rules | Queensbury Rules
# 1918106 | Queensland Street Kids | Queensland Street Kids  (2002)
# 1944453 | Quei due sopra il varano | Quei due sopra il varano  (1996)
# 48338 | Queimada | Queimada
# 1987779 | Quel do Paje | Quel do Paje  (1969)
# 197963 | Quelle drle de gosse! | Quelle drle de gosse!
# 191819 | Quelle famille! | Quelle famille!
# 48439 | Quelli che... aspettano | Quelli che... aspettano
# 1945471 | Quelli che... il calcio | Quelli che... il calcio
# 48440 | Quelli che... ultimo minuto | Quelli che... ultimo minuto
# 477085 | Quem  Beta? | Quem  Beta?
# 500386 | Quem s Tu? | Quem s Tu?
# 500586 | Quemar las naves | Quemar las naves  (2007)
# 199620 | Quemar las naves | Quemar las naves
# 486388 | Quentin | Quentin  (2002)
# 200733 | Quentin Durgens, M.P. | Quentin Durgens, M.P.
# 196056 | Quenton | Quenton
# 1987897 | Querida Matilde | Querida Matilde  (2005)
# 493220 | Queridsimos verdugos | Queridsimos verdugos  (1977)
# 509070 | Quero Ser Uma Estrela | Quero Ser Uma Estrela
# 486893 | Quest for the Meaning of Life | Quest for the Meaning of Life
# 476963 | Questa  la mia terra | Questa  la mia terra
# 483162 | Questioni di pelle | Questioni di pelle
# 502510 | Questo piccolo grande amore | Questo piccolo grande amore  (2009)
# 47989 | Questo sporco mondo meraviglioso | Questo sporco mondo meraviglioso
# 50709 | Quezon City | Quezon City  (2004)
# 1965380 | Qui | Qui  (1997)
# 192314 | Qui ose nous accuser? | Qui ose nous accuser?
# 1999671 | Qui t'estima, Babel? | Qui t'estima, Babel?  (1987)
# 1957663 | Quick Step Beyond | Quick Step Beyond
# 481617 | Quick as a Flash | Quick as a Flash
# 484455 | Quicksand Castles | Quicksand Castles  (2011)
# 200307 | Quicktrip | Quicktrip
# 1989489 | Quien baila mejor? | Quien baila mejor?  (2007)
# 494894 | Quien? | Quien?
# 497113 | Quieres Que Me Muera | Quieres Que Me Muera  (2010)
# 1942598 | Quiero ser famoso por un da | Quiero ser famoso por un da
# 198361 | Quiet | Quiet
# 195038 | Quiet Wedding | Quiet Wedding
# 192252 | Quietly on By | Quietly on By  (2005)
# 488975 | Quietos todos | Quietos todos
# 1989537 | Quin dira | Quin dira  (2001)
# 1921234 | Quin quiere ver pelculas sobre la dictadura? | Quin quiere ver pelculas sobre la dictadura?
# 1943972 | Quince | Quince  (1998)
# 194474 | Quinneys | Quinneys  (1927)
# 198546 | Quintin | Quintin
# 50513 | Quintin Salazar | Quintin Salazar
# 494911 | Quireme con msica | Quireme con msica
# 50625 | Quireme porque me muero | Quireme porque me muero
# 496015 | Quite Contrary! Mary Woronov, My Life as a Cult Queen - From Warhol to Corman | Quite Contrary! Mary Woronov, My Life as a Cult Queen - From Warhol to Corman
# 485364 | Quittance | Quittance
# 48151 | Quo Vadis, Baby? | Quo Vadis, Baby?
# 48152 | Quore | Quore
# 1997985 | Quotation Marks | Quotation Marks
# 489180 | R U Invited? | R U Invited?  (2006)
# 482912 | R'coon Dawg | R'coon Dawg
# 482754 | R.C. Presents New Faces' | R.C. Presents New Faces'
# 1968802 | R.E.M. | R.E.M.  (2007)
# 480261 | R.I.P. - Repose en paix | R.I.P. - Repose en paix  (2003)
# 479780 | R.I.P. repose en paix | R.I.P. repose en paix  (2005)
# 478263 | R.I.P., Rest in Pieces | R.I.P., Rest in Pieces  (1997)
# 196100 | R.T.T. | R.T.T.  (2009)
# 482563 | RCVR | RCVR  (2011)
# 479801 | RE:Brand | RE:Brand  (2002)
# 50371 | RPG Metanoia | RPG Metanoia
# 197976 | RRRrrrr!!! | RRRrrrr!!!
# 48048 | RSM, el resumen de los medios | RSM, el resumen de los medios
# 1978446 | RTL II News | RTL II News
# 1992391 | Rabab | Rabab  (1942)
# 485302 | Rabbids Go Home | Rabbids Go Home  (2009)
# 505805 | Rabbit | Rabbit  (1998)
# 1926390 | Rabbit Tales | Rabbit Tales  (1992)
# 48891 | Rabbit, Run | Rabbit, Run
# 193528 | Rabbit-Proof Fence | Rabbit-Proof Fence
# 1945665 | Rabbits, Jackasses, & Four-Letter Words | Rabbits, Jackasses, & Four-Letter Words
# 49574 | Rabljeva freska | Rabljeva freska
# 1992155 | Raccontami | Raccontami  (2006)
# 1929423 | Race Around Oz | Race Around Oz
# 2005670 | Race Suicide | Race Suicide  (1937)
# 501483 | Race Walkers | Race Walkers
# 493224 | Race d'Ep | Race d'Ep
# 505377 | Race to the Altar | Race to the Altar
# 507493 | Racer Number 9 | Racer Number 9
# 500779 | Races de odio | Races de odio
# 1989 | Racha, chemi sikvaruli | Racha, chemi sikvaruli
# 1941072 | Rache fr Eddy | Rache fr Eddy  (1929)
# 497313 | Rachel's Return | Rachel's Return
# 492928 | Racin' for a Livin' | Racin' for a Livin'
# 1913668 | Racing Around the Clock | Racing Around the Clock
# 50824 | Racing Stripes | Racing Stripes  (2005)
# 48829 | Racing Youth | Racing Youth
# 483759 | Rack | Rack  (2010)
# 196760 | Rackety Rax | Rackety Rax
# 504585 | Radiant | Radiant  (2005)
# 50184 | Radiation | Radiation  (1999)
# 20004 | Radio Cape Cod | Radio Cape Cod
# 50842 | Radio Corazn | Radio Corazn
# 19729 | Radio K-KUM | Radio K-KUM
# 193198 | Radio Luxemburg | Radio Luxemburg  (2010)
# 485046 | Radio On: The Shawn & Hobby Band Documentary | Radio On: The Shawn & Hobby Band Documentary
# 19099 | Radio Patrol | Radio Patrol
# 50147 | Radio Pirates | Radio Pirates
# 480204 | Radio Prayer | Radio Prayer
# 195221 | Radiofieber | Radiofieber
# 476962 | Radioportogutemberg | Radioportogutemberg
# 1946426 | Rafa | Rafa
# 493889 | Raffaello | Raffaello
# 1926026 | Rafferty's Rules | Rafferty's Rules  (1987)
# 1944598 | Ragazzi de' borgata | Ragazzi de' borgata
# 483601 | Rage of the Innocents | Rage of the Innocents
# 508675 | Rage: 20 Years of Punk Rock West Coast Style | Rage: 20 Years of Punk Rock West Coast Style  (2001)
# 199963 | Rage: 20 Years of Punk Rock West Coast Style | Rage: 20 Years of Punk Rock West Coast Style
# 482913 | Raggedy Ann and Raggedy Andy | Raggedy Ann and Raggedy Andy
# 1921372 | Raggidy End | Raggidy End  (2009)
# 1990648 | Ragnarok | Ragnarok
# 501268 | Rags and the Girl | Rags and the Girl
# 191351 | Ragtime Cowboy Joe | Ragtime Cowboy Joe
# 490628 | Rah! Rah! Rexie! | Rah! Rah! Rexie!
# 48978 | Raid on Rommel | Raid on Rommel
# 19100 | Raiders of Ghost City | Raiders of Ghost City
# 481709 | Raiders of Old California | Raiders of Old California
# 191352 | Raiders of Sunset Pass | Raiders of Sunset Pass
# 19101 | Raiders of the Border | Raiders of the Border
# 193688 | Rain Clouds | Rain Clouds
# 1927838 | Rain in Spain | Rain in Spain
# 502126 | Rain, Drizzle, and Fog | Rain, Drizzle, and Fog  (1998)
# 505670 | Rainbow Bridge | Rainbow Bridge
# 48830 | Rainbow Over Broadway | Rainbow Over Broadway
# 1947101 | Rainbow Over Texas | Rainbow Over Texas  (1946)
# 193434 | Rainbow Riley | Rainbow Riley
# 1922567 | Rainbow Road | Rainbow Road
# 1921593 | Rainbow Tramp | Rainbow Tramp  (2011)
# 490026 | Rainbow of Emotion | Rainbow of Emotion  (2010)
# 505185 | Rainbows End | Rainbows End
# 502378 | Raindogs | Raindogs
# 1929178 | Raintree County | Raintree County  (1957)
# 500551 | Raio - XYZ | Raio - XYZ  (2010)
# 192168 | Raised Alone | Raised Alone
# 492261 | Raisin' Trouble | Raisin' Trouble
# 1940310 | Raising the Roof | Raising the Roof  (1972)
# 1955993 | Raithe Raju | Raithe Raju
# 1902506 | Raja Gopichand | Raja Gopichand
# 1985101 | Rajio no jikan | Rajio no jikan  (1997)
# 1955994 | Raktha Sambandhalu | Raktha Sambandhalu
# 1969411 | Raleigh | Raleigh
# 193944 | Rally On | Rally On
# 200243 | Ralph Talk | Ralph Talk
# 1945346 | Ralph: Someone to Me | Ralph: Someone to Me  (2009)
# 196165 | Ramadi 2-17 | Ramadi 2-17
# 1945926 | Ramas | Ramas  (2008)
# 485147 | Ramblin' Gal | Ramblin' Gal
# 477653 | Ramblin' Gal | Ramblin' Gal  (1991)
# 1990 | Ramdenime interviu pirad sakitkhebze | Ramdenime interviu pirad sakitkhebze
# 193965 | Ramen Noodles | Ramen Noodles  (2009)
# 1957771 | Ramge | Ramge
# 50050 | Ramnerea | Ramnerea
# 494158 | Ramona and Beezus | Ramona and Beezus
# 191773 | Ramrod | Ramrod
# 506336 | Ranch Girls on a Rampage | Ranch Girls on a Rampage
# 1937432 | Ranchers and Rascals | Ranchers and Rascals  (1925)
# 190981 | Ranczo Wilkowyje | Ranczo Wilkowyje
# 482295 | Randgnger | Randgnger
# 1904335 | Random Access Memory | Random Access Memory  (2009)
# 1902961 | Random Acts | Random Acts  (2007)
# 1971999 | Random Acts of Duff | Random Acts of Duff
# 504771 | Random Acts of Truth and Other White Lies | Random Acts of Truth and Other White Lies
# 19475 | Random Harvest | Random Harvest
# 486753 | Random Violence | Random Violence
# 1961703 | Random. | Random.
# 499333 | Randy Turpin vs. Bobo Olson | Randy Turpin vs. Bobo Olson
# 19102 | Range Defenders | Range Defenders
# 494061 | Rangeland | Rangeland
# 191353 | Ranger of Cherokee Strip | Ranger of Cherokee Strip
# 19103 | Ranger's Code | Ranger's Code
# 478033 | Ranma : Ch-musabetsu kessen! Ranma team VS densetsu no h | Ranma : Ch-musabetsu kessen! Ranma team VS densetsu no h
# 478034 | Ranma : Chgoku Nekonron daikessen! Okite yaburi no gekit hen | Ranma : Chgoku Nekonron daikessen! Okite yaburi no gekit hen
# 478035 | Ranma : Kessen Tgenky! Hanayome o torimodose!! | Ranma : Kessen Tgenky! Hanayome o torimodose!!
# 1947446 | Raoul et Lili | Raoul et Lili  (1994)
# 1917071 | Rap Sucks | Rap Sucks  (2011)
# 483489 | Rap Therapy | Rap Therapy
# 501649 | Rapa Nui: Legends in Stone | Rapa Nui: Legends in Stone
# 2000282 | Rapace | Rapace  (2006)
# 494380 | Raphal le tatou | Raphal le tatou  (1939)
# 200618 | Raphal ou le dbauch | Raphal ou le dbauch
# 48507 | Rapid Fire | Rapid Fire  (1989)
# 505923 | Rapscallions | Rapscallions  (1999)
# 498369 | Rapsodia gaucha | Rapsodia gaucha
# 500122 | Rapsodia mexicana | Rapsodia mexicana
# 477509 | Rapstarz | Rapstarz
# 19787 | Rapture | Rapture
# 1963698 | Rapunzel: The Blonde Years | Rapunzel: The Blonde Years  (2008)
# 488559 | Rasputin - Orgien am Zarenhof | Rasputin - Orgien am Zarenhof  (1984)
# 199249 | Ratapln | Ratapln
# 494882 | Ratas de la ciudad | Ratas de la ciudad
# 483635 | Ratcatcher | Ratcatcher
# ...
# 1994818 | Synco-Smooth Swing | Synco-Smooth Swing  (1945)
# 485266 | Syncopation and Song | Syncopation and Song  (1927)
# 1994113 | Syngue sabour | Syngue sabour
# 1917976 | Syntax Error | Syntax Error  (2003)
# 501174 | Syntax; | Syntax;  (2008)
# 1918011 | Syntax; | Syntax;
# 194620 | Synthetic Pleasures | Synthetic Pleasures
# 49562 | Syphon Filter: Dark Mirror | Syphon Filter: Dark Mirror
# 1987110 | Syrenernas tid | Syrenernas tid  (2002)
# 1955498 | Syri magjik | Syri magjik  (2005)
# 191805 | Syri magjik | Syri magjik
# 482 | Sysmlinen | Sysmlinen
# 47718 | Szabadsg, szerelem | Szabadsg, szerelem  (2006)
# 1978079 | Szamotas Geliebte | Szamotas Geliebte
# 194846 | Szeret fia, Pter | Szeret fia, Pter  (1942)
# 1930945 | Szindbd | Szindbd  (1971)
# 47873 | Szke kla | Szke kla
# 192264 | Szkice weglem | Szkice weglem
# 1928121 | Szp csillag | Szp csillag  (1942)
# 506837 | Szven szrt orszg | Szven szrt orszg  (2009)
# 1976600 | Szvet szvrt | Szvet szvrt  (1938)
# 1935572 | T'amer sempre | T'amer sempre  (1943)
# 1930589 | T'was the Night | T'was the Night
# 500832 | T-Bone | T-Bone  (2005)
# 482923 | T-Bone for Two | T-Bone for Two
# 502774 | T-Shirt | T-Shirt
# 477619 | T.H.E.M. | T.H.E.M.
# 1956801 | T.I.O.T: Tomorrow Is Only Tuesday | T.I.O.T: Tomorrow Is Only Tuesday
# 483741 | T.N.M. | T.N.M.
# 194338 | Tams s Juli | Tams s Juli
# 508958 | Tanarexia | Tanarexia  (2008)
# 483170 | Tanganyika | Tanganyika  (1954)
# 19754 | Tangerine | Tangerine
# 505464 | Tangled Trails | Tangled Trails
# 48703 | Tangled by Telephone | Tangled by Telephone
# 1928545 | Tango Flush | Tango Flush
# 504 | Tango Kabaree | Tango Kabaree
# 1930952 | Tango Notturno | Tango Notturno  (1937)
# 488313 | Tango durch Deutschland | Tango durch Deutschland
# 493211 | Tango, the Obsession | Tango, the Obsession
# 200177 | Tangy Guacamole | Tangy Guacamole
# 1993671 | Tanja - Die Nackte von der Teufelsinsel | Tanja - Die Nackte von der Teufelsinsel
# 49728 | Tank | Tank
# 49154 | Tankov brigda | Tankov brigda
# 48120 | Tannenberg | Tannenberg
# 508627 | Tanner '88 | Tanner '88  (1988)
# 1953412 | Tanner on Tanner | Tanner on Tanner  (2004)
# 1945736 | Tano da morire | Tano da morire
# 1933864 | Tansi! Nehiyawetan | Tansi! Nehiyawetan  (2011)
# 508744 | Tante Zita | Tante Zita
# 49585 | Tanz in der Sonne | Tanz in der Sonne
# 496519 | Tanzende Sterne | Tanzende Sterne
# 498778 | Taong putik | Taong putik
# 196486 | Tap Roots | Tap Roots
# 197967 | Tapage nocturne | Tapage nocturne
# 487117 | Tape 407 | Tape 407
# 508583 | Taperaksje | Taperaksje
# 482582 | Taphephobia | Taphephobia
# 488275 | Tapinarii | Tapinarii
# 1992367 | Tappion tunne - Magnus Scharmanoff valokuvaaja | Tappion tunne - Magnus Scharmanoff valokuvaaja
# 1988882 | Tara Calico: Gone Without a Trace | Tara Calico: Gone Without a Trace
# 198230 | Tara Road | Tara Road
# 1952314 | Taranthriller | Taranthriller  (1997)
# 501909 | Tarantyno | Tarantyno
# 495247 | Taratabong! | Taratabong!
# 50910 | Taray at Teroy | Taray at Teroy
# 481442 | Target of an Assassin | Target of an Assassin  (1978)
# 200660 | Target of an Assassin | Target of an Assassin
# 197211 | Target: Harry | Target: Harry  (1969)
# 1993 | Tariel Golua | Tariel Golua
# 50428 | Tarima | Tarima
# 198072 | Tarnished | Tarnished
# 496528 | Tarot | Tarot  (2009)
# 479658 | Tarps Elin | Tarps Elin  (1956)
# 1959504 | Tarte aux pommes | Tarte aux pommes
# 2001939 | Tarzan and the Amazons | Tarzan and the Amazons  (1945)
# 200599 | Tarzan and the Leopard Woman | Tarzan and the Leopard Woman
# 498084 | Tarzan the Ape Man | Tarzan the Ape Man
# 486801 | Tarzan's Greatest Adventure | Tarzan's Greatest Adventure
# 193755 | Tarzan's Magic Fountain | Tarzan's Magic Fountain
# 490716 | Tarzan's Peril | Tarzan's Peril  (1951)
# 193756 | Tarzan's Savage Fury | Tarzan's Savage Fury
# 489641 | Tarzan's Secret Treasure | Tarzan's Secret Treasure
# 48255 | Tarzn en las minas del rey Salomn | Tarzn en las minas del rey Salomn
# 1933689 | Tarzun and the Valley of Lust | Tarzun and the Valley of Lust
# 490951 | Tasmanian Tapestry | Tasmanian Tapestry  (1953)
# 1913894 | Taste in Powder | Taste in Powder  (2010)
# 47875 | Tempo | Tempo
# 504580 | Tempo di Reazione | Tempo di Reazione
# 498200 | Tempo di credere | Tempo di credere
# 481787 | Tempo di riposo | Tempo di riposo
# 192308 | Tempo massimo | Tempo massimo
# 48404 | Tempo! Tempo! | Tempo! Tempo!
# 500920 | Temporale Rosy | Temporale Rosy
# 506345 | Temporary Marriage | Temporary Marriage
# 1956280 | Temptation: The Story of a Lustful Bride | Temptation: The Story of a Lustful Bride  (1984)
# 194309 | Tempte dans un verre d'eau | Tempte dans un verre d'eau  (1997)
# 195743 | Tempted by Necessity | Tempted by Necessity
# 505760 | Ten Adventures of a Lifetime | Ten Adventures of a Lifetime  (2004)
# 50800 | Ten Days to Tulara | Ten Days to Tulara
# 507451 | Ten Minutes Older: The Cello | Ten Minutes Older: The Cello
# 479459 | Ten Seconds to Midnight | Ten Seconds to Midnight
# 490380 | Ten Thousand Talents | Ten Thousand Talents
# 483808 | Ten for Two: The John Sinclair Freedom Rally | Ten for Two: The John Sinclair Freedom Rally

# %% [markdown]
# d) Ispisati minimalnu i maksimalnu vrijednost indeksa i pripadnih podataka za te indekse.

# %%
def find_min_max_indices(root: BinaryNode) -> tuple[MoviesData, MoviesData]:
    
    max_string = ""
    min_string = "\U0010FFFF" * 100
    min_movie = None
    max_movie = None

    def traverse_check_min_max(node: BinaryNode) -> None:

        nonlocal min_string, max_string, min_movie, max_movie

        if node is None:
            return
        
        if node.value < min_string:
            min_string = node.value
            min_movie = node.movie

        if node.value > max_string:
            max_string = node.value
            max_movie = node.movie

        traverse_check_min_max(node.left)
        traverse_check_min_max(node.right)

    traverse_check_min_max(root)
    return min_movie, max_movie

min_movie, max_movie = find_min_max_indices(myTree.root)

print(f'Min indeks: {min_movie.short_name}, podatak: {min_movie}')
print(f'Max indeks: {max_movie.short_name}, podatak: {max_movie}')
# Out:
# Min indeks: #Indignados, podatak: 50162 | #Indignados | #Indignados  (2011)
# Max indeks: ventyr i pyjamas, podatak: 191030 | ventyr i pyjamas | ventyr i pyjamas

# %% [markdown]
# e) Za proizvoljno zadani cijeli broj koji će imati značenje rednog broja te slijedom toga ispisati visinu čvora koji se nalazi na tom rednom broju u uzlazno sortiranom redoslijedu indeksnih ključeva stabla.

# %%
def get_sorted_indices(movies: list[MoviesData]) -> list[str]:
    names = list(map(lambda m: m.short_name, movies))
    names.sort()
    return names

def print_node_height(node: BinaryNode, num: int, indices: list[str]) -> None:
    index = indices[num - 1]
    
    def traverse_print_height(node: BinaryNode) -> None:
        
        nonlocal index

        if node is None:
            return

        if node.value == index:
            print(f'Found {index} at height {node.height}')
            return

        traverse_print_height(node.left)
        traverse_print_height(node.right)

    traverse_print_height(node)

indices = get_sorted_indices(movies)
num = 551
print_node_height(myTree.root, num, indices)
# Out:
# Found A Law Unto Herself at height 1

# %% [markdown]
# f) Napraviti metode za ispis broja lijevih rotacija i broja desnih rotacija kod umetanja čvora u stablo.

# %%
def search_node(key: str, root: BinaryNode) -> BinaryNode:
    if root is None or root.value == key:
        return root
    if key > root.value:
        return search_node(key, root.right)
    return search_node(key, root.left)

def print_rotations(movie_name: str, tree: BinaryTree) -> None:
    node = search_node(movie_name, tree.root)
    print(f'Rotations for movie {movie_name}: {node.left_rotations} left, {node.right_rotations} right.')

for m in movies[:5]:
    print_rotations(m.short_name, myTree)
# Out:
# Rotations for movie A Yank in Viet-Nam: 7 left, 7 right.
# Rotations for movie Jayam Kondaan: 3 left, 3 right.
# Rotations for movie The Phoenix and the Carpet: 4 left, 3 right.
# Rotations for movie Lucid Possession: 2 left, 1 right.
# Rotations for movie The Fakers: 3 left, 4 right.

# %% [markdown]
# g) Ispisati stablo po razinama počevši od korijena prema dolje u cik-cak redoslijedu. To znači da se čvorovi na prvoj razini ispisuju s lijeva na desno, na drugoj razini s desna na lijevo, pa na trećoj razini s lijeva na desno itd. Ispis raditi po razinama, odnosno svaku razinu ispisati u posebnom retku.
# Primjer za stablo na slici treba dobiti sljedeći ispis:

# %%
from collections import deque

def print_levels_zig_zag(root: BinaryNode, max_levels: int) -> None:

    if not root:
        return
    
    queue = deque([root])
    level = 0
    
    while level < max_levels:

        level_size = len(queue)
        current_level = []
        
        for _ in range(level_size):

            node = queue.popleft()
            current_level.append(node.value)
            
            if node.left:
                queue.append(node.left)
            
            if node.right:
                queue.append(node.right)

        if level % 2 == 0:
            print(' || '.join(current_level))
        else:
            print(' || '.join(reversed(current_level)))
        #print(' || '.join(current_level))

        level += 1

print_levels_zig_zag(myTree.root, 10)
# Out:
# Or Else Alone
# The End: Chapter 2 - The Casting Couch || Esok masih ada
# Chan's Beach || Law of the Ranger || Ruby & Lilly Kick the Habit || Trilogia - Il pensiero, lo sguardo, la parola
# What Is a Picture? || The Phoenix and the Carpet || Som e Fria - O Filme || Raja Gopichand || Ms all del corazn || Jayam Kondaan || Deedar || Aventuri la Marea Neagra
# Aau fung yee || Bloomberg Morning News || Country Girls in Heat || Du bois pour l'hiver || Gza mshvidobisa, Jako! || L'art || Lucid Possession || Notorious C.H.O. || Piata || Rincon criollo || Seemabaddha || Telegrama Nmero Nove || The Latest Vampire || The Truck of Dreams || Valadio, o Cratera || Women of Glamour
# Z Bolas e o Famoso Telegrama No. 9 || White Way, a Life Experience || Vrooom Vroom Vrooom || Un dentiste exemplaire || Tianshi qingren || The Secret Fury || The Moon Stalker || The Groan || The Blue Marble || Stozeit - Rush Hour || Shirley Chisholm for President || Sarang sarang nae sarang || Romance of the West || Regular Maintenance || Presena de Marisa || Panna Nikt || Ojos que no duermen || Nam yan chi fu || Maski || Life Begins with Love || La mujer murcilago || Kasei no waga ya || Hyn huet ching nin || Furesshuman wakadaish || El farol de la ventana || Dirty Diamonds Are Forever || Das Sonntagskonzert || Clothes and the Woman || Bubblepac || Basketball Wives LA || American Seoul || A Gosto do Fregus
me95 || The Mysterious Mr. Valentine || The Mr. Men Movie || The Moss Witch || The Money Jungle || The Mighty || The Meaning of Food || The Marriage Business || The Male Animal || The Loves of Mary, Queen of Scots || The Locker || The Library Rose || The Last Guy || The Lady Lies || The Killing Time || The Joan Edwards Show || The Invisible Killer || The Hurricane Express || The Hitch-Hiker || The Handmaid's Tale || The Great St. Trinian's Train Robbery || The Gong Show || The Girls Are Bustin' Loose || The Gift Wrapper || The Gang Buster || The Floating World || The Fiancee and the Fairy || The Exquisite Corpse Project || The Drum Beats Twice || The Debut || The Cross Bearer || The Corner Man || The Cloud of Unknowing || The Casino Murder Case || The Burtons || The Boy Princes: A Tragedie Most Monstrous || The Black Parachute || The Big One || The Battle for Moser River || The Baby || The Amati Girls || The Absence of Emily || That Night with You || Terapia || Tea Date || Tango Notturno || Tag || Szkice weglem || Sweet and Innocent || Surprise Gardener || Sulkary || Strigoi || Stolen Moment || Steamrollers: Not Just for Crushing People || Stand By All Networks || Spyro 2: Ripto's Rage! || Speedy || Soup || Sonny and Cornblatt || Sometimes People... || Sol d'estiu || So Faraway and Blue || Smash-Up: The Story of a Woman || Slaughter Is the Best Medicine || Sit and Spin || Singing Guns || Silent Night Bloody Night || Shri Satyanarayan || Sheriff of Sundown || She Has What It Takes || Shadowed || Sexual Harassment Orientation || Sex Ed || Servez-vous mesdames || Sensationsprozess Casilla || Seka's Fantasies || Seduction of the Will || Secret Knives || Search || Screenplay || Scnarios sur la drogue: Tube d'un jour || Schlsselreiz - ...

# %% [markdown]
# h) Nasumično birati zapise iz skupa podataka i graditi obično nebalansirano binarno stablo pretraživanja sve dok je to moguće. Zabilježiti visinu takvog nebalansiranog stabla te ponoviti postupak za isti niz zapisa u izgradnji AVL stabla za koji također treba zabilježiti visinu dobivenog stabla.

# %%
class BinaryNodeNonAVL:

    def __init__ (self, value = None, movie = None):
        """Create binary node."""
        self.value  = value
        self.left   = None
        self.right  = None
        self.height = 0
        self.movie = movie
        
    def computeHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.height)
        if self.right:
            height = max(height, self.right.height)
            
        self.height = height + 1

    def dynamicHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.dynamicHeight())
        if self.right:
            height = max(height, self.right.dynamicHeight())
            
        return height + 1

    def dynamicHeightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.dynamicHeight()
        if self.right:
            rightTarget = 1 + self.right.dynamicHeight()
            
        return leftTarget - rightTarget

    def heightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.height
        if self.right:
             rightTarget = 1 + self.right.height
                   
        return leftTarget - rightTarget

    def compareTo (self, value):
        """
        Returns 0 if equal, negative if smaller and positive if greater.
        Suitable for overriding.
        """
        if self.value == value:
            return 0
        if self.value < value:
            return -1
        return +1
    
    # Izbrisane rotacije
    def add (self, val, movie):
        """Adds a new node to BST with value."""
        newRoot = self
      
        if self.compareTo(val) >= 0:
            self.left = self.addToSubTree (self.left, val, movie)
        else:
            self.right = self.addToSubTree (self.right, val, movie)

        newRoot.computeHeight()
        return newRoot

    # Dodan parametar movie
    def newNode (self, val, movie):
        """Return new Binary Node, amenable to subclassing."""
        return BinaryNodeNonAVL(val, movie)

    # Dodan parametar movie
    def addToSubTree (self, parent, val, movie):
        """Add val to parent subtree (if exists) and return root in case it has changed because of rotation."""
        if parent is None:
            return self.newNode(val, movie)
        parent = parent.add(val, movie)
        return parent
           
    def removeFromParent (self, parent, val):
        """Helper method for remove. Ensures proper behavior when removing node that 
        has children."""
        if parent:
            return parent.remove(val)
        return None

    def remove (self, val):
        """
         Remove val from BinaryTree. Works in conjunction with remove
         method in BinaryTree.
        """
        newRoot = self
        rc = self.compareTo(val)
        if rc == 0:
            if self.left is None:
                return self.right

            child = self.left
            while child.right:
                child = child.right
            
            childKey = child.value;
            self.left = self.removeFromParent(self.left, childKey)
            self.value = childKey;

        elif rc > 0:
            self.left = self.removeFromParent(self.left, val)
        else:
            self.right = self.removeFromParent(self.right, val)

        newRoot.computeHeight()
        return newRoot

    def __repr__ (self):
        """Useful debugging function to produce linear tree representation."""
        leftS = ''
        rightS = ''
        if self.left:
            leftS = str(self.left)
        if self.right:
            rightS = str(self.right)
        return "(L:" + leftS + " " + str(self.value) + " R:" + rightS + ")"

    def inorder (self):
        """In order traversal generator of tree rooted at given node."""
        if self.left:
            for n in self.left.inorder():
                yield n

        yield self.value

        if self.right:
            for n in self.right.inorder():
                yield n

class BinaryTreeNonAVL:

    def __init__ (self):
        """Create empty binary tree."""
        self.root = None

    def __repr__ (self):
        if self.root is None:
            return "avl:()"
        return "avl:" + str(self.root)
    
    # Dodan parametar movie
    def newNode (self, value, movie):
        """Return new BinaryNode object. Suitable for overriding."""
        return BinaryNodeNonAVL(value, movie)
    
    # Dodan parametar movie
    def add (self, value, movie):
        """Insert value into proper location in Binary Tree."""
        if self.root is None:
            self.root = self.newNode(value, movie)
        else:
            self.root = self.root.add(value, movie)

    def __contains__ (self, target):
        """Check whether BST contains target value."""
        node = self.root
        while node:
            rc = node.compareTo(target)
            if rc > 0:
                node = node.left
            elif rc < 0:
                node = node.right
            else:
                return True
        return False

           
    def remove (self, val):
        """Remove value from tree."""
        if self.root:
            self.root = self.root.remove(val)

    def __iter__ (self):          # definira iteriranje kroz inorder ispis
        """In order traversal of elements in the tree."""
        if self.root:
            return self.root.inorder()
                        
    def assertAVLProperty (self):
        """Validate AVL property for BST Tree."""
        if self.root:
            return self.root.assertAVLProperty()
        else:
            return True

# %%
import random

binaryTree = BinaryTreeNonAVL()
AVLTree = BinaryTree()

movies = get_movies_from_file()

random.seed(50)
random.shuffle(movies)

while movies:
    m = movies.pop()
    binaryTree.add(m.short_name, m)
    AVLTree.add(m.short_name, m)

print(f'Visina nebalansiranog stabla: {binaryTree.root.height}')
print(f'Visina balansiranog stabla: {AVLTree.root.height}')
# Out:
# Visina nebalansiranog stabla: 35
# Visina balansiranog stabla: 17
